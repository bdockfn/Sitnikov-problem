# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import matplotlib.animation as animation
# %matplotlib widget

from calc_module import *

# %%
a = 1/2
e = 0.001
N = 100
time_step = 0.1
period = 2*np.pi

y0 = initial_grid_zv(-6, 6, -2, 2, 0.5)

res = solution(y0, a, e, period, N, time_step)

# %%
def show(res):
    z = res[:,0]
    v = res[:,1]

    plt.style.use('seaborn')
    fig = plt.figure(figsize = (5, 5))
    plt.scatter(z, v, color = 'red', s = 0.03)
    plt.xlim(-6, 6)
    #plt.ylim(-2, 2)
    plt.show()
show(res)
# Out:
# /tmp/ipykernel_14831/3401514385.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5, 5))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
